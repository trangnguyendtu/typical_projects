# %%
import warnings

warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### get movie id & movie title & movie rating, skip the timestamp at the last column (no use of timestamp)

# %%
ratingCols = ["user_id", "movie_id", "rating"]
ratings = pd.read_csv(
    "../ml-100k/u.data",
    sep="\t",
    names=ratingCols,
    usecols=range(3),
    encoding="ISO-8859-1",
)

movieCols = ["movie_id", "title"]
movies = pd.read_csv(
    "../ml-100k/u.item",
    sep="|",
    names=movieCols,
    usecols=range(2),
    encoding="ISO-8859-1",
)

ratings = pd.merge(movies, ratings)

# %%
ratings.head(25)
# Out:
#     movie_id             title  user_id  rating
# 0          1  Toy Story (1995)      308       4
# 1          1  Toy Story (1995)      287       5
# 2          1  Toy Story (1995)      148       4
# 3          1  Toy Story (1995)      280       4
# 4          1  Toy Story (1995)       66       3
# 5          1  Toy Story (1995)        5       4
# 6          1  Toy Story (1995)      109       4
# 7          1  Toy Story (1995)      181       3
# 8          1  Toy Story (1995)       95       5
# 9          1  Toy Story (1995)      268       3
# 10         1  Toy Story (1995)      189       5
# 11         1  Toy Story (1995)      145       3
# 12         1  Toy Story (1995)      158       4
# 13         1  Toy Story (1995)       67       3
# 14         1  Toy Story (1995)      232       4
# 15         1  Toy Story (1995)      150       4
# 16         1  Toy Story (1995)      289       3
# 17         1  Toy Story (1995)      117       4
# 18         1  Toy Story (1995)       49       2
# 19         1  Toy Story (1995)      223       4
# 20         1  Toy Story (1995)       56       4
# 21         1  Toy Story (1995)       17       4
# 22         1  Toy Story (1995)      340       5
# 23         1  Toy Story (1995)      177       3
# 24         1  Toy Story (1995)      194       4

# %%
ratings.groupby("title")["rating"].describe()
# Out:
#                                        count      mean       std  min   25%  \
# title
# 'Til There Was You (1997)                9.0  2.333333  1.000000  1.0  2.00
# 1-900 (1994)                             5.0  2.600000  1.516575  1.0  1.00
# 101 Dalmatians (1996)                  109.0  2.908257  1.076184  1.0  2.00
# 12 Angry Men (1957)                    125.0  4.344000  0.719588  2.0  4.00
# 187 (1997)                              41.0  3.024390  1.172344  1.0  2.00
# ...                                      ...       ...       ...  ...   ...
# Young Guns II (1990)                    44.0  2.772727  1.008421  1.0  2.00
# Young Poisoner's Handbook, The (1995)   41.0  3.341463  1.237129  1.0  3.00
# Zeus and Roxanne (1997)                  6.0  2.166667  0.983192  1.0  1.25
# unknown                                  9.0  3.444444  1.130388  1.0  3.00
# Á köldum klaka (Cold Fever) (1994)       1.0  3.000000       NaN  3.0  3.00
#
#                                        50%  75%  max
# title
# 'Til There Was You (1997)              2.0  3.0  4.0
# 1-900 (1994)                           3.0  4.0  4.0
# 101 Dalmatians (1996)                  3.0  4.0  5.0
# 12 Angry Men (1957)                    4.0  5.0  5.0
# 187 (1997)                             3.0  4.0  5.0
# ...                                    ...  ...  ...
# Young Guns II (1990)                   3.0  3.0  5.0
# Young Poisoner's Handbook, The (1995)  4.0  4.0  5.0
# Zeus and Roxanne (1997)                2.5  3.0  3.0
# unknown                                4.0  4.0  5.0
# Á köldum klaka (Cold Fever) (1994)     3.0  3.0  3.0
#
# [1664 rows x 8 columns]

# %%
userRatings = ratings.pivot_table(index=["user_id"], columns=["title"], values="rating")

# %%
userRatings.head(25)
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# 6                              NaN           NaN                    NaN
# 7                              NaN           NaN                    NaN
# 8                              NaN           NaN                    NaN
# 9                              NaN           NaN                    NaN
# 10                             NaN           NaN                    NaN
# 11                             NaN           NaN                    NaN
# 12                             NaN           NaN                    NaN
# 13                             NaN           NaN                    2.0
# 14                             NaN           NaN                    NaN
# 15                             NaN           NaN                    3.0
# 16                             NaN           NaN                    NaN
# 17                             NaN           NaN                    NaN
# 18                             NaN           NaN                    NaN
# 19                             NaN           NaN                    NaN
# 20                             NaN           NaN                    NaN
# 21                             NaN           NaN                    NaN
# 22                             NaN           NaN                    NaN
# 23                             NaN           NaN                    NaN
# 24                             NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
# 6                        4.0         NaN                          NaN
# 7                        4.0         NaN                          NaN
# 8                        NaN         NaN                          NaN
# 9                        NaN         NaN                          NaN
# 10                       5.0         NaN                          NaN
# 11                       NaN         NaN                          NaN
# 12                       NaN         NaN                          NaN
# 13                       4.0         NaN                          NaN
# 14                       NaN         NaN                          NaN
# 15                       NaN         NaN                          NaN
# 16                       5.0         NaN                          NaN
# 17                       NaN         NaN                          NaN
# 18                       3.0         NaN                          NaN
# 19                       NaN         NaN                          NaN
# 20                       NaN         NaN                          NaN
# 21                       NaN         4.0                          NaN
# 22                       NaN         NaN                          NaN
# 23                       NaN         NaN                          NaN
# 24                       5.0         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 0                                        NaN                           NaN
# 1                                        3.0                           4.0
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# 5                                        NaN                           4.0
# 6                                        NaN                           5.0
# 7                                        5.0                           5.0
# 8                                        NaN                           NaN
# 9                                        NaN                           NaN
# 10                                       NaN                           5.0
# 11                                       NaN                           4.0
# 12                                       NaN                           NaN
# 13                                       2.0                           5.0
# 14                                       NaN                           NaN
# 15                                       NaN                           NaN
# 16                                       NaN                           4.0
# 17                                       NaN                           NaN
# 18                                       NaN                           3.0
# 19                                       NaN                           NaN
# 20                                       NaN                           NaN
# 21                                       NaN                           NaN
# 22                                       NaN                           NaN
# 23                                       NaN                           NaN
# 24                                       NaN                           NaN
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                1.0                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# 5                                                NaN                   NaN
# 6                                                NaN                   NaN
# 7                                                NaN                   4.0
# 8                                                NaN                   NaN
# 9                                                NaN                   4.0
# 10                                               NaN                   4.0
# 11                                               NaN                   NaN
# 12                                               NaN                   NaN
# 13                                               1.0                   4.0
# 14                                               NaN                   NaN
# 15                                               NaN                   NaN
# 16                                               NaN                   NaN
# 17                                               NaN                   NaN
# 18                                               NaN                   NaN
# 19                                               NaN                   NaN
# 20                                               NaN                   NaN
# 21                                               NaN                   NaN
# 22                                               NaN                   NaN
# 23                                               NaN                   NaN
# 24                                               NaN                   NaN
#
# title    ...  Yankee Zulu (1994)  Year of the Horse (1997)  \
# user_id  ...
# 0        ...                 NaN                       NaN
# 1        ...                 NaN                       NaN
# 2        ...                 NaN                       NaN
# 3        ...                 NaN                       NaN
# 4        ...                 NaN                       NaN
# 5        ...                 NaN                       NaN
# 6        ...                 NaN                       NaN
# 7        ...                 NaN                       NaN
# 8        ...                 NaN                       NaN
# 9        ...                 NaN                       NaN
# 10       ...                 NaN                       NaN
# 11       ...                 NaN                       NaN
# 12       ...                 NaN                       NaN
# 13       ...                 NaN                       2.0
# 14       ...                 NaN                       NaN
# 15       ...                 NaN                       NaN
# 16       ...                 NaN                       NaN
# 17       ...                 NaN                       NaN
# 18       ...                 NaN                       NaN
# 19       ...                 NaN                       NaN
# 20       ...                 NaN                       NaN
# 21       ...                 NaN                       NaN
# 22       ...                 NaN                       NaN
# 23       ...                 NaN                       NaN
# 24       ...                 NaN                       NaN
#
# title    You So Crazy (1994)  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# 0                        NaN                        NaN                NaN
# 1                        NaN                        5.0                3.0
# 2                        NaN                        NaN                NaN
# 3                        NaN                        NaN                NaN
# 4                        NaN                        NaN                NaN
# 5                        NaN                        4.0                NaN
# 6                        NaN                        4.0                NaN
# 7                        NaN                        5.0                3.0
# 8                        NaN                        NaN                NaN
# 9                        NaN                        NaN                NaN
# 10                       NaN                        NaN                NaN
# 11                       NaN                        4.0                NaN
# 12                       NaN                        NaN                NaN
# 13                       NaN                        5.0                3.0
# 14                       NaN                        NaN                NaN
# 15                       NaN                        NaN                NaN
# 16                       NaN                        5.0                NaN
# 17                       NaN                        NaN                NaN
# 18                       NaN                        4.0                NaN
# 19                       NaN                        NaN                NaN
# 20                       NaN                        2.0                NaN
# 21                       NaN                        NaN                NaN
# 22                       NaN                        5.0                NaN
# 23                       NaN                        NaN                NaN
# 24                       NaN                        NaN                NaN
#
# title    Young Guns II (1990)  Young Poisoner's Handbook, The (1995)  \
# user_id
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# 5                         NaN                                    NaN
# 6                         NaN                                    NaN
# 7                         NaN                                    3.0
# 8                         NaN                                    NaN
# 9                         NaN                                    NaN
# 10                        NaN                                    NaN
# 11                        NaN                                    NaN
# 12                        NaN                                    NaN
# 13                        NaN                                    1.0
# 14                        NaN                                    NaN
# 15                        NaN                                    NaN
# 16                        NaN                                    NaN
# 17                        NaN                                    NaN
# 18                        NaN                                    NaN
# 19                        NaN                                    NaN
# 20                        NaN                                    NaN
# 21                        NaN                                    2.0
# 22                        NaN                                    NaN
# 23                        NaN                                    NaN
# 24                        NaN                                    NaN
#
# title    Zeus and Roxanne (1997)  unknown  Á köldum klaka (Cold Fever) (1994)
# user_id
# 0                            NaN      NaN                                 NaN
# 1                            NaN      4.0                                 NaN
# 2                            NaN      NaN                                 NaN
# 3                            NaN      NaN                                 NaN
# 4                            NaN      NaN                                 NaN
# 5                            NaN      4.0                                 NaN
# 6                            NaN      NaN                                 NaN
# 7                            NaN      NaN                                 NaN
# 8                            NaN      NaN                                 NaN
# 9                            NaN      NaN                                 NaN
# 10                           NaN      NaN                                 NaN
# 11                           NaN      NaN                                 NaN
# 12                           NaN      NaN                                 NaN
# 13                           NaN      NaN                                 NaN
# 14                           NaN      NaN                                 NaN
# 15                           NaN      NaN                                 NaN
# 16                           NaN      NaN                                 NaN
# 17                           NaN      NaN                                 NaN
# 18                           NaN      NaN                                 NaN
# 19                           NaN      NaN                                 NaN
# 20                           NaN      NaN                                 NaN
# 21                           NaN      NaN                                 NaN
# 22                           NaN      NaN                                 NaN
# 23                           NaN      NaN                                 NaN
# 24                           NaN      NaN                                 NaN
#
# [25 rows x 1664 columns]

# %%
ratingsMean = ratings.groupby("title")["rating"].describe()["mean"]

# %%
ratingsMean
# Out:
# title
# 'Til There Was You (1997)                2.333333
# 1-900 (1994)                             2.600000
# 101 Dalmatians (1996)                    2.908257
# 12 Angry Men (1957)                      4.344000
# 187 (1997)                               3.024390
#                                            ...
# Young Guns II (1990)                     2.772727
# Young Poisoner's Handbook, The (1995)    3.341463
# Zeus and Roxanne (1997)                  2.166667
# unknown                                  3.444444
# Á köldum klaka (Cold Fever) (1994)       3.000000
# Name: mean, Length: 1664, dtype: float64

# %% [markdown]
# ## use corr() method of pandas, compute correlation score of every pair of movies

# %%
corrCompute = userRatings.corr()
corrCompute.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        1.0           NaN
# 1-900 (1994)                                     NaN           1.0
# 101 Dalmatians (1996)                           -1.0           NaN
# 12 Angry Men (1957)                             -0.5           NaN
# 187 (1997)                                      -0.5           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)              -1.000000            -0.500000
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                   1.000000            -0.049890
# 12 Angry Men (1957)                    -0.049890             1.000000
# 187 (1997)                              0.269191             0.666667
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# 'Til There Was You (1997)   -0.500000                     0.522233
# 1-900 (1994)                      NaN                          NaN
# 101 Dalmatians (1996)        0.269191                     0.048973
# 12 Angry Men (1957)          0.666667                     0.256625
# 187 (1997)                   1.000000                     0.596644
#
# title                      20,000 Leagues Under the Sea (1954)  \
# title
# 'Til There Was You (1997)                                  NaN
# 1-900 (1994)                                               NaN
# 101 Dalmatians (1996)                                 0.266928
# 12 Angry Men (1957)                                   0.274772
# 187 (1997)                                                 NaN
#
# title                      2001: A Space Odyssey (1968)  \
# title
# 'Til There Was You (1997)                     -0.426401
# 1-900 (1994)                                  -0.981981
# 101 Dalmatians (1996)                         -0.043407
# 12 Angry Men (1957)                            0.178848
# 187 (1997)                                    -0.554700
#
# title                      3 Ninjas: High Noon At Mega Mountain (1998)  \
# title
# 'Til There Was You (1997)                                          NaN
# 1-900 (1994)                                                       NaN
# 101 Dalmatians (1996)                                              NaN
# 12 Angry Men (1957)                                                NaN
# 187 (1997)                                                         NaN
#
# title                      39 Steps, The (1935)  ...  Yankee Zulu (1994)  \
# title                                            ...
# 'Til There Was You (1997)                   NaN  ...                 NaN
# 1-900 (1994)                                NaN  ...                 NaN
# 101 Dalmatians (1996)                  0.111111  ...                 NaN
# 12 Angry Men (1957)                    0.457176  ...                 NaN
# 187 (1997)                             1.000000  ...                 NaN
#
# title                      Year of the Horse (1997)  You So Crazy (1994)  \
# title
# 'Til There Was You (1997)                       NaN                  NaN
# 1-900 (1994)                                    NaN                  NaN
# 101 Dalmatians (1996)                     -1.000000                  NaN
# 12 Angry Men (1957)                             NaN                  NaN
# 187 (1997)                                 0.866025                  NaN
#
# title                      Young Frankenstein (1974)  Young Guns (1988)  \
# title
# 'Til There Was You (1997)                        NaN                NaN
# 1-900 (1994)                               -0.944911                NaN
# 101 Dalmatians (1996)                       0.158840           0.119234
# 12 Angry Men (1957)                         0.096546           0.068944
# 187 (1997)                                  0.455233          -0.500000
#
# title                      Young Guns II (1990)  \
# title
# 'Til There Was You (1997)                   NaN
# 1-900 (1994)                                NaN
# 101 Dalmatians (1996)                  0.680414
# 12 Angry Men (1957)                   -0.361961
# 187 (1997)                             0.500000
#
# title                      Young Poisoner's Handbook, The (1995)  \
# title
# 'Til There Was You (1997)                                    NaN
# 1-900 (1994)                                                 NaN
# 101 Dalmatians (1996)                              -4.875600e-17
# 12 Angry Men (1957)                                 1.443376e-01
# 187 (1997)                                          4.753271e-01
#
# title                      Zeus and Roxanne (1997)  unknown  \
# title
# 'Til There Was You (1997)                      NaN      NaN
# 1-900 (1994)                                   NaN      NaN
# 101 Dalmatians (1996)                     0.707107      NaN
# 12 Angry Men (1957)                       1.000000      1.0
# 187 (1997)                                     NaN      NaN
#
# title                      Á köldum klaka (Cold Fever) (1994)
# title
# 'Til There Was You (1997)                                 NaN
# 1-900 (1994)                                              NaN
# 101 Dalmatians (1996)                                     NaN
# 12 Angry Men (1957)                                       NaN
# 187 (1997)                                                NaN
#
# [5 rows x 1664 columns]

# %% [markdown]
# ### restrict the result with min_periods to keep only pairs rated by at least 100 users, ensuring more popular and recognizable results

# %%
corrCompute = userRatings.corr(method="pearson", min_periods=100)

# %%
corrCompute.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        NaN           NaN
# 1-900 (1994)                                     NaN           NaN
# 101 Dalmatians (1996)                            NaN           NaN
# 12 Angry Men (1957)                              NaN           NaN
# 187 (1997)                                       NaN           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)                    NaN                  NaN
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                        1.0                  NaN
# 12 Angry Men (1957)                          NaN                  1.0
# 187 (1997)                                   NaN                  NaN
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# 'Til There Was You (1997)         NaN                          NaN
# 1-900 (1994)                      NaN                          NaN
# 101 Dalmatians (1996)             NaN                          NaN
# 12 Angry Men (1957)               NaN                          NaN
# 187 (1997)                        NaN                          NaN
#
# title                      20,000 Leagues Under the Sea (1954)  \
# title
# 'Til There Was You (1997)                                  NaN
# 1-900 (1994)                                               NaN
# 101 Dalmatians (1996)                                      NaN
# 12 Angry Men (1957)                                        NaN
# 187 (1997)                                                 NaN
#
# title                      2001: A Space Odyssey (1968)  \
# title
# 'Til There Was You (1997)                           NaN
# 1-900 (1994)                                        NaN
# 101 Dalmatians (1996)                               NaN
# 12 Angry Men (1957)                                 NaN
# 187 (1997)                                          NaN
#
# title                      3 Ninjas: High Noon At Mega Mountain (1998)  \
# title
# 'Til There Was You (1997)                                          NaN
# 1-900 (1994)                                                       NaN
# 101 Dalmatians (1996)                                              NaN
# 12 Angry Men (1957)                                                NaN
# 187 (1997)                                                         NaN
#
# title                      39 Steps, The (1935)  ...  Yankee Zulu (1994)  \
# title                                            ...
# 'Til There Was You (1997)                   NaN  ...                 NaN
# 1-900 (1994)                                NaN  ...                 NaN
# 101 Dalmatians (1996)                       NaN  ...                 NaN
# 12 Angry Men (1957)                         NaN  ...                 NaN
# 187 (1997)                                  NaN  ...                 NaN
#
# title                      Year of the Horse (1997)  You So Crazy (1994)  \
# title
# 'Til There Was You (1997)                       NaN                  NaN
# 1-900 (1994)                                    NaN                  NaN
# 101 Dalmatians (1996)                           NaN                  NaN
# 12 Angry Men (1957)                             NaN                  NaN
# 187 (1997)                                      NaN                  NaN
#
# title                      Young Frankenstein (1974)  Young Guns (1988)  \
# title
# 'Til There Was You (1997)                        NaN                NaN
# 1-900 (1994)                                     NaN                NaN
# 101 Dalmatians (1996)                            NaN                NaN
# 12 Angry Men (1957)                              NaN                NaN
# 187 (1997)                                       NaN                NaN
#
# title                      Young Guns II (1990)  \
# title
# 'Til There Was You (1997)                   NaN
# 1-900 (1994)                                NaN
# 101 Dalmatians (1996)                       NaN
# 12 Angry Men (1957)                         NaN
# 187 (1997)                                  NaN
#
# title                      Young Poisoner's Handbook, The (1995)  \
# title
# 'Til There Was You (1997)                                    NaN
# 1-900 (1994)                                                 NaN
# 101 Dalmatians (1996)                                        NaN
# 12 Angry Men (1957)                                          NaN
# 187 (1997)                                                   NaN
#
# title                      Zeus and Roxanne (1997)  unknown  \
# title
# 'Til There Was You (1997)                      NaN      NaN
# 1-900 (1994)                                   NaN      NaN
# 101 Dalmatians (1996)                          NaN      NaN
# 12 Angry Men (1957)                            NaN      NaN
# 187 (1997)                                     NaN      NaN
#
# title                      Á köldum klaka (Cold Fever) (1994)
# title
# 'Til There Was You (1997)                                 NaN
# 1-900 (1994)                                              NaN
# 101 Dalmatians (1996)                                     NaN
# 12 Angry Men (1957)                                       NaN
# 187 (1997)                                                NaN
#
# [5 rows x 1664 columns]

# %% [markdown]
# ## add my own rating to the dataset to check if the recommended system is correct
# ### user_id = 0, love Titanic, Gone with the wind, Addicted to love, Forrest Gump, and hate Star Wars

# %%
myRatings = userRatings.loc[0].dropna()
myRatings
# Out:
# title
# Addicted to Love (1997)      4.0
# Forrest Gump (1994)          4.0
# Gone with the Wind (1939)    5.0
# Star Wars (1977)             1.0
# Titanic (1997)               5.0
# Name: 0, dtype: float64

# %% [markdown]
# ### get similar movies with the correlation matrix

# %%
similarCandidates = pd.Series()
for i in range(0, len(myRatings.index)):
    sims = corrCompute[myRatings.index[i]].dropna()
    sims = sims.map(lambda x: x * myRatings[i])
    similarCandidates = pd.concat([similarCandidates, sims])

similarCandidates = similarCandidates.groupby(similarCandidates.index).sum()
similarCandidates.sort_values(inplace=True, ascending=False)

# %%
similarCandidates.head(10)
# Out:
# Titanic (1997)                               5.860437
# Forrest Gump (1994)                          5.631674
# Gone with the Wind (1939)                    5.495449
# E.T. the Extra-Terrestrial (1982)            5.127360
# Raiders of the Lost Ark (1981)               4.093941
# Braveheart (1995)                            4.034450
# Schindler's List (1993)                      3.861449
# Indiana Jones and the Last Crusade (1989)    3.818921
# Return of the Jedi (1983)                    3.818239
# Dances with Wolves (1990)                    3.714286
# dtype: float64

# %% [markdown]
# ### filter myRating movies (Titanic,...)

# %%
filteredMovies = similarCandidates.drop(myRatings.index, errors="ignore")
filteredMovies.head(10)
# Out:
# E.T. the Extra-Terrestrial (1982)            5.127360
# Raiders of the Lost Ark (1981)               4.093941
# Braveheart (1995)                            4.034450
# Schindler's List (1993)                      3.861449
# Indiana Jones and the Last Crusade (1989)    3.818921
# Return of the Jedi (1983)                    3.818239
# Dances with Wolves (1990)                    3.714286
# Independence Day (ID4) (1996)                3.687819
# Jurassic Park (1993)                         3.584174
# Back to the Future (1985)                    3.421730
# dtype: float64

# %%
sns.lineplot(data=filteredMovies.head(10).sort_values(ascending=False))
plt.title("Top 10 similar movies")
plt.xlabel("Movie")
plt.ylabel("Similarity Score")
plt.xticks(rotation=90)
plt.show()
